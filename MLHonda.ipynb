# %%
from pyspark.sql.functions import col, median, when, isnan, count, sum
from pyspark.sql.functions import mean, stddev
from pyspark.ml.feature import OneHotEncoder, StringIndexer, VectorAssembler, StandardScaler
from pyspark.ml import Pipeline
from pyspark.sql.types import IntegerType
from pyspark.sql.types import FloatType
from pyspark.sql.types import DoubleType
from pyspark.sql.functions import regexp_replace, col
from pyspark.sql import SparkSession
from pyspark.sql import functions as F

# %%
df = spark.sql("SELECT * from honda")
df.show(4)

# %% [markdown]
# ### Delete All nulls columns

# %%
# Count null values in all columns
null_counts = df.select(
    *[sum(when(col(c).isNull(), 1).otherwise(0)).alias(c) for c in df.columns]
)

# Show the null counts
display(null_counts)

# %%
columns_with_nulls = [c for c in null_counts.columns if null_counts.first()[c] > 0]

# Delete columns with null values

df_clean = df.drop(*columns_with_nulls)

# %%
df_clean.show(5)

# %% [markdown]
# ### Fix data type

# %%
df_clean.printSchema()

# %%
# Change data type of Year, Consumer_Rating, Consumer_Review_#)
df_clean = df_clean.withColumn("Year", col("Year").cast(IntegerType())) \
                       .withColumn("Consumer_Rating", col("Consumer_Rating").cast(FloatType())) \
                       .withColumn("Consumer_Review_#", col("Consumer_Review_#").cast(FloatType()))

# %%
df_clean.printSchema()

# %% [markdown]
# ### Clean and normalize price

# %%
# Creteate new column "Price_int" from "Price""
df_clean = df_clean.withColumn("Price_int", 
                   regexp_replace(col("Price"), r"\$|,", "").cast(DoubleType()))

# %%
df_clean.show(5)

# %%
df_clean.printSchema()

# %% [markdown]
# ### Count models and add them as a new column

# %%
model_count = df_clean.groupBy("Model").count().orderBy("count", ascending=False)

# %%
model_count = model_count.withColumnRenamed("count", "model_count")

# %%
# Unir los conteos de vuelta al DataFrame original
df_clean = df_clean.join(model_count, on="Model", how="left")

# %%
df_clean.show(5)

# %% [markdown]
# ### Calculate mode of model_count

# %%
# Calculate mode of model_count
mode_value = df_clean.groupBy("model_count") \
    .count() \
    .orderBy(F.desc("count")) \
    .first()["model_count"]

# %%
# Añadir la moda como una nueva columna en el DataFrame
df_clean = df_clean.withColumn("mode_model_count", F.lit(mode_value))

# %%
df_clean.show(5)

# %% [markdown]
# ### One Hot Encoding

# %%
df_clean = df_clean.withColumn("condicion", when(col("condition") == "New", 0.30)
                              .when(col("condition") == "Honda Certified", 0.20)
                              .when(col("condition") == "Used", 0.16)
                              .otherwise(0.0))

# %%
df_clean = df_clean.withColumn("factor_oferta", (col("model_count") / col("mode_model_count")) * 0.05)
df_clean = df_clean.withColumn("factor_rating", (1 - (col("Consumer_rating") / 10)) * 0.05)

# %%
df_clean.show(5)

# %% [markdown]
# ### Delete rows with price_int null

# %%
# Eliminar todas las filas que tienen algún valor NULL
df_clean = df_clean.na.drop()

# %%
# Count null values in all columns
null_counts = df_clean.select(
    *[sum(when(col(c).isNull(), 1).otherwise(0)).alias(c) for c in df_clean.columns]
)

# Show the null counts
display(null_counts)

# %% [markdown]
# ### Training and evaluating model

# %%
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.regression import RandomForestRegressor
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.sql.functions import col
from mlflow import MlflowClient
import mlflow

# %%
mlflow.set_experiment("/Users/sergiosl@alumni.mioti.es/DepreciationModel")

# %%
feature_columns = ["Year", "Consumer_Rating", "Consumer_Review_#", "model_count", "mode_model_count", "factor_oferta", "factor_rating"]
target_column = "Price_int"

# %%
assembler = VectorAssembler(inputCols=feature_columns, outputCol="features")
df_transform = assembler.transform(df_clean).select("features", target_column)

# %%
train_df, test_df = df_transform.randomSplit([0.8, 0.2], seed=42)

# %%
print(train_df.columns)

# %%
rf = RandomForestRegressor(featuresCol="features", labelCol=target_column, maxDepth=10, numTrees=50)
model = rf.fit(train_df)

# %%
# Definir diferentes configuraciones de hiperparámetros
param_grid = [
    {"maxDepth": 5, "numTrees": 30},
    {"maxDepth": 10, "numTrees": 50},
    {"maxDepth": 15, "numTrees": 70}
]
for params in param_grid:
    with mlflow.start_run():
        rf = RandomForestRegressor(featuresCol="features", labelCol=target_column, 
                                   maxDepth=params["maxDepth"], numTrees=params["numTrees"])
        model = rf.fit(train_df)
        
        # Evaluar modelo en test
        predictions = model.transform(test_df)
        
        # Asegurar que la predicción nunca supere Precio_int
        predictions = predictions.withColumn("prediction", when(col("prediction") > col(target_column), col(target_column)).otherwise(col("prediction")))
        
        evaluator = RegressionEvaluator(labelCol=target_column, predictionCol="prediction", metricName="rmse")
        rmse = evaluator.evaluate(predictions)
        
        # Guardar métricas e hiperparámetros en MLflow
        mlflow.log_param("maxDepth", params["maxDepth"])
        mlflow.log_param("numTrees", params["numTrees"])
        mlflow.log_metric("rmse", rmse)
        mlflow.spark.log_model(model, "depreciation_model")
        
        print(f"Iteración con maxDepth={params['maxDepth']}, numTrees={params['numTrees']} -> RMSE: {rmse}")

# %%
# Mostrar resultados
test_df.select("features", target_column).show(5)

# %%
df_transform.orderBy("Year").show(5)

# %% [markdown]
# ### Define Catalog and Schema in Unity Catalog

# %%
import mlflow
from pyspark.ml.regression import RandomForestRegressor
from pyspark.ml.evaluation import RegressionEvaluator
from mlflow.models.signature import infer_signature
from pyspark.ml.classification import RandomForestClassifier
from pyspark.ml.evaluation import MulticlassClassificationEvaluator

# %%
catalog = "mlhonda"
schema = "default"

# %%
mlflow.set_registry_uri("databricks-mlhonda")

# %% [markdown]
# Load Data

# %%
df_clean.show(5)

# %%
# Definir las columnas de características y la columna objetivo
feature_columns = ["Year", "Consumer_Rating", "Consumer_Review_#", "model_count", "mode_model_count", "factor_oferta", "factor_rating"]
target_column = "Price_int"

# %%
for column in feature_columns:
    df_clean = df_clean.withColumn(column,  col(column).cast(FloatType()))

# %%
# Convertir la columna objetivo a double
df_clean = df_clean.withColumn(target_column, col(target_column).cast(DoubleType()))

# %%
df_clean.printSchema()

# %%
# Aplicar el VectorAssembler
assembler = VectorAssembler(inputCols=feature_columns, outputCol="features")
df_transform = assembler.transform(df_clean).select("features", target_column)

# %%
# Verificar el esquema de df_transform
df_transform.printSchema()

# %%
df_transform.printSchema()

# Dividir los datos en conjuntos de entrenamiento y prueba
(train_data, test_data) = df_transform.randomSplit([0.7, 0.3])

# %%
# Verificar los esquemas de train_data y test_data
train_data.printSchema()
test_data.printSchema()

# %% [markdown]
# ## Train Data

# %%
from pyspark.ml.regression import RandomForestRegressor
from pyspark.ml.evaluation import RegressionEvaluator

# Crear y entrenar el modelo RandomForestRegressor
rf = RandomForestRegressor(featuresCol="features", labelCol=target_column, maxDepth=10, numTrees=50)
model = rf.fit(train_data)
model_name = 'mlhonda'

# Hacer predicciones
predictions = model.transform(test_data)

# Evaluar el modelo utilizando RMSE
evaluator = RegressionEvaluator(labelCol=target_column, predictionCol="prediction", metricName="rmse")
rmse = evaluator.evaluate(predictions)
print(f"RMSE: {rmse}")

# Evaluar el modelo utilizando R2
evaluator = RegressionEvaluator(labelCol=target_column, predictionCol="prediction", metricName="r2")
r2 = evaluator.evaluate(predictions)
print(f"R2: {r2}")

# %% [markdown]
# ### Model Signature

# %%
# Sample Data
sample = train_data.limit(5)
# Convert Spark DataFrame to Pandas DataFrame
train_data_pd = sample.toPandas()
# Infer model signature using the Pandas DataFrame
signature = infer_signature(train_data_pd, model.transform(sample).toPandas())

# %%
train_data_pd.head()

# %% [markdown]
# ### Login MlFlow

# %%
with mlflow.start_run():
    mlflow.spark.log_model(model, model_name, signature=signature)
    uri = mlflow.get_artifact_uri(model_name)
    # Log metrics
    mlflow.log_metric("accuracy_score", r2)
    # Register Model
    mlflow.register_model(
        model_uri=uri,
        name=f"{catalog}.{schema}.{model_name}",
    )

# %% [markdown]
# ### Create Alias for latest version of model

# %%
# Initialize the MLflow client
client = MlflowClient()

# Search for all versions of the model and fetch the latest one
model_version_infos = client.search_model_versions(f"name='{catalog}.{schema}.{model_name}'")
new_model_version = max(model_version_info.version for model_version_info in model_version_infos)

# Set the alias for the latest model version
client.set_registered_model_alias(
    name=f"{catalog}.{schema}.{model_name}",
    alias="Best",
    version=new_model_version
)

# %%
model_version_uri = 'models:/'+f"{catalog}.{schema}.{model_name}@Best"
best_version = mlflow.spark.load_model(model_version_uri)

# %%
display(best_version.transform(test_data).limit(5))
